# %%
import numpy as np

from function_modules.function_module import *

# %%
# Shared directory to save results 
shared_data_dir = 'Data/parameter_testing/selection/'

# Shared GA parameters
kwargs = {
    'cnn_model_path': '../../Models/CNN_6_1_2.keras',
    'masked_sequence': 'AATACTAGAGGTCTTCCGACNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNGTGTGGGCGGGAAGACAACTAGGGG',
    'seed': 0,
}

# Testing parameters
target_expressions = [0, 0.5, 1]
lineages = 10
test_cases = 11

# %%
# Varying elitism_rate
param_ranges = {
    'elitism_rate' : np.linspace(0, 1, test_cases),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}elitism_rate.csv')
# Out:
# Processing combinations:  45%|████▌     | 150/330 [07:21<08:14,  2.75s/it, Elapsed=7.36min, ETA=8.84min]
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 0
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 1
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 2
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 3
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 4
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 5
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 6
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 7
# Error: integer modulo by zero
# Params: {'elitism_rate': 0.5}, Target Expression: 0, Lineage: 8
# ...

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}elitism_rate.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'elitism_rate', polynomial_degree=2)
# Out:
# Optimal elitism_rate for error: 0.1 (Minimum error: 0.136)
# Relationship between elitism_rate and error:
#   - Correlation Coefficient (r): 0.879
#   - p-value: 2.635e-20
#   - Significant
#
# Optimal elitism_rate for run_time: 1.0 (Minimum run_time: 0.069)
# Relationship between elitism_rate and run_time:
#   - Correlation Coefficient (r): -0.907
#   - p-value: 1.886e-23
#   - Significant
# Optimal elitism_rate for error: 0.0 (Minimum error: 0.000)
# Relationship between elitism_rate and error:
#   - Correlation Coefficient (r): 0.726
#   - p-value: 5.417e-11
#   - Significant
#
# Optimal elitism_rate for run_time: 1.0 (Minimum run_time: 0.051)
# Relationship between elitism_rate and run_time:
#   - Correlation Coefficient (r): -0.966
#   - p-value: 1.358e-35
#   - Significant
# Optimal elitism_rate for error: 0.1 (Minimum error: 0.163)
# Relationship between elitism_rate and error:
#   - Correlation Coefficient (r): 0.898
#   - p-value: 2.571e-22
#   - Significant
#
# ...

# %%
# Varying survival_rate
param_ranges = {
    'survival_rate' : np.linspace(0.1, 1, test_cases-1),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}survival_rate.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 300/300 [18:12<00:00,  3.64s/it, Elapsed=18.22min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}survival_rate.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'survival_rate', polynomial_degree=2)
# Out:
# Optimal survival_rate for error: 1.0 (Minimum error: 0.130)
# Relationship between survival_rate and error:
#   - Correlation Coefficient (r): -0.292
#   - p-value: 3.190e-03
#   - Significant
#
# Optimal survival_rate for run_time: 1.0 (Minimum run_time: 2.733)
# Relationship between survival_rate and run_time:
#   - Correlation Coefficient (r): 0.050
#   - p-value: 6.232e-01
#   - Not Significant
# Optimal survival_rate for error: 0.5 (Minimum error: 0.000)
# Relationship between survival_rate and error:
#   - Correlation Coefficient (r): -0.046
#   - p-value: 6.490e-01
#   - Not Significant
#
# Optimal survival_rate for run_time: 1.0 (Minimum run_time: 2.852)
# Relationship between survival_rate and run_time:
#   - Correlation Coefficient (r): 0.127
#   - p-value: 2.072e-01
#   - Not Significant
# Optimal survival_rate for error: 0.8 (Minimum error: 0.148)
# Relationship between survival_rate and error:
#   - Correlation Coefficient (r): -0.261
#   - p-value: 8.706e-03
# ...

# %%
# Run for selTournament, varying tournsize
param_ranges = {
    'selection_method' : ['selTournament'],
    'tournsize' : np.linspace(1, 10, test_cases-1, dtype=int),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}selTournament.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 300/300 [19:03<00:00,  3.81s/it, Elapsed=19.05min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}selTournament.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'tournsize', polynomial_degree=2)
# Out:
# Optimal tournsize for error: 3 (Minimum error: 0.125)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.448
#   - p-value: 3.004e-06
#   - Significant
#
# Optimal tournsize for run_time: 10 (Minimum run_time: 3.367)
# Relationship between tournsize and run_time:
#   - Correlation Coefficient (r): -0.679
#   - p-value: 8.623e-15
#   - Significant
# Optimal tournsize for error: 2 (Minimum error: 0.000)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.398
#   - p-value: 4.175e-05
#   - Significant
#
# Optimal tournsize for run_time: 6 (Minimum run_time: 3.250)
# Relationship between tournsize and run_time:
#   - Correlation Coefficient (r): -0.833
#   - p-value: 5.837e-27
#   - Significant
# Optimal tournsize for error: 3 (Minimum error: 0.154)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.415
#   - p-value: 1.798e-05
#   - Significant
#
# ...

# %%
# Run for selBoltzmann, varying tournsize
param_ranges = {
    'selection_method' : ['selBoltzmann'],
    'boltzmann_temperature' : np.linspace(0.1, 1, test_cases-1),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}selBoltzmann.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 300/300 [22:29<00:00,  4.50s/it, Elapsed=22.50min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}selBoltzmann.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'boltzmann_temperature', polynomial_degree=2)
# Out:
# Optimal boltzmann_temperature for error: 0.1 (Minimum error: 0.164)
# Relationship between boltzmann_temperature and error:
#   - Correlation Coefficient (r): 0.489
#   - p-value: 2.506e-07
#   - Significant
#
# Optimal boltzmann_temperature for run_time: 0.1 (Minimum run_time: 4.013)
# Relationship between boltzmann_temperature and run_time:
#   - Correlation Coefficient (r): 0.048
#   - p-value: 6.368e-01
#   - Not Significant
# Optimal boltzmann_temperature for error: 0.2 (Minimum error: 0.000)
# Relationship between boltzmann_temperature and error:
#   - Correlation Coefficient (r): 0.515
#   - p-value: 4.204e-08
#   - Significant
#
# Optimal boltzmann_temperature for run_time: 0.9 (Minimum run_time: 4.035)
# Relationship between boltzmann_temperature and run_time:
#   - Correlation Coefficient (r): -0.347
#   - p-value: 4.008e-04
#   - Significant
# Optimal boltzmann_temperature for error: 0.1 (Minimum error: 0.186)
# Relationship between boltzmann_temperature and error:
# ...

# %%
# Run for selTournamentWithoutReplacement, varying tournsize
param_ranges = {
    'selection_method' : ['selTournamentWithoutReplacement'],
    'tournsize' : np.linspace(1, 10, test_cases-1, dtype=int),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}selTournamentWithoutReplacement.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 300/300 [19:20<00:00,  3.87s/it, Elapsed=19.34min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}selTournamentWithoutReplacement.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'tournsize', polynomial_degree=2)
# Out:
# Optimal tournsize for error: 8 (Minimum error: 0.132)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.496
#   - p-value: 1.592e-07
#   - Significant
#
# Optimal tournsize for run_time: 7 (Minimum run_time: 3.448)
# Relationship between tournsize and run_time:
#   - Correlation Coefficient (r): -0.669
#   - p-value: 2.890e-14
#   - Significant
# Optimal tournsize for error: 3 (Minimum error: 0.000)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.300
#   - p-value: 2.461e-03
#   - Significant
#
# Optimal tournsize for run_time: 9 (Minimum run_time: 3.420)
# Relationship between tournsize and run_time:
#   - Correlation Coefficient (r): -0.783
#   - p-value: 6.825e-22
#   - Significant
# Optimal tournsize for error: 3 (Minimum error: 0.139)
# Relationship between tournsize and error:
#   - Correlation Coefficient (r): -0.420
#   - p-value: 1.381e-05
#   - Significant
#
# ...

# %%
# Evaluate the selection methods without additional parameters
param_ranges = {
    'selection_method' : ['selRandom', 'selBest', 'selRoulette', 'selStochasticUniversalSampling', 'selNormRoulette'],
}
no_param_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate selTournament
param_ranges = {
    'selection_method' : ['selTournament'],
    'tournsize' : [5],
}
selTournament_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate selBoltzmann
param_ranges = {
    'selection_method' : ['selBoltzmann'],
    'boltzmann_temperature' : [0.1],
}
selBoltzmann_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate selTournamentWithoutReplacement
param_ranges = {
    'selection_method' : ['selTournamentWithoutReplacement'],
    'tournsize' : [5],
}
selTournamentWithoutReplacement_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Concatenate all results, and save to csv
results_df = pd.concat([no_param_df, selTournament_df, selBoltzmann_df, selTournamentWithoutReplacement_df])
results_df.to_csv(f'{shared_data_dir}selection_comparison.csv', index=False)
# Out:
# Processing combinations:   0%|          | 0/150 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# ...
# Processing combinations: 100%|██████████| 30/30 [01:50<00:00,  3.69s/it, Elapsed=1.84min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}selection_comparison.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    distribution_plot(filtered_df, target_expression, 'selection_method')
# Out:
# Optimal selection_method for error: selBest (Average error: 0.139)
# ANOVA Test for error by selection_method:
#   - F-statistic: 99.689
#   - p-value: 1.866e-34
#   - Significant
#
# Optimal selection_method for run_time: selTournamentWithoutReplacement (Average run_time: 3.420)
# ANOVA Test for run_time by selection_method:
#   - F-statistic: 45.016
#   - p-value: 8.046e-24
#   - Significant
# Optimal selection_method for error: selBest (Average error: 0.000)
# ANOVA Test for error by selection_method:
#   - F-statistic: 12.098
#   - p-value: 4.176e-10
#   - Significant
#
# Optimal selection_method for run_time: selTournament (Average run_time: 3.363)
# ANOVA Test for run_time by selection_method:
#   - F-statistic: 61.315
#   - p-value: 8.329e-28
#   - Significant
# Optimal selection_method for error: selBest (Average error: 0.148)
# ANOVA Test for error by selection_method:
#   - F-statistic: 96.738
#   - p-value: 4.933e-34
#   - Significant
#
# ...

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}selection_comparison.csv')
filtered_df = results_df[results_df['target_expression'] != 0.5]
distribution_plot(filtered_df, '0 and 1', 'selection_method')
# Out:
# c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\function_modules\function_module.py:317: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.9))
# c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\function_modules\function_module.py:324: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.9))
# Optimal selection_method for error: selBest (Average error: 0.144)
# ANOVA Test for error by selection_method:
#   - F-statistic: 16.791
#   - p-value: 2.603e-16
#   - Significant
#
# ...

# %% [markdown]
# ### Testing convergence
# ---

# %%
target_expressions = [0]

# All selection methods
param_ranges = {
    'selection_method' : ['selBest', 'selBoltzmann', 'selNormRoulette', 'selRandom', 'selRoulette', 'selStochasticUniversalSampling', 'selTournament', 'selTournamentWithoutReplacement'],
}
results_dfs = test_param_convergence(param_ranges, target_expressions, lineages, kwargs)
# Out:
# Processing combinations:   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# ...

# %%
convergence_fill_between(results_dfs)

# %%
filtered_dfs = {
    ('selBest',): results_dfs[('selBest',)],
    ('selTournament',) : results_dfs[('selTournament',)],
    ('selTournamentWithoutReplacement',) : results_dfs[('selTournamentWithoutReplacement',)],
}

# %%
convergence_fill_between(filtered_dfs)
