# %%
import numpy as np

from function_modules.function_module import *

# %%
# Shared directory to save results 
shared_data_dir = 'Data/parameter_testing/crossover/'

# Shared GA parameters
kwargs = {
    'cnn_model_path': '../../Models/CNN_6_1_2.keras',
    'masked_sequence': 'AATACTAGAGGTCTTCCGACNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNGTGTGGGCGGGAAGACAACTAGGGG',
    'seed': 0,
}

# Testing parameters
target_expressions = [0, 0.5, 1]
lineages = 10
test_cases = 11

# %%
# Run for cxOnePoint, varying crossover rate
param_ranges = {
    'crossover_method' : ['cxOnePoint'],
    'crossover_rate' : np.linspace(0.01, 1.0, test_cases)
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}cxOnePoint.csv')
# Out:
# Processing combinations:   0%|          | 0/330 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 330/330 [25:51<00:00,  4.70s/it, Elapsed=25.86min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}cxOnePoint.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'crossover_rate', polynomial_degree=2)
# Out:
# Optimal crossover_rate for error: 1.0 (Minimum error: 0.131)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.200
#   - p-value: 3.609e-02
#   - Significant
#
# Optimal crossover_rate for run_time: 0.01 (Minimum run_time: 2.936)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.083
#   - p-value: 3.903e-01
#   - Not Significant
# Optimal crossover_rate for error: 0.109 (Minimum error: 0.000)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): 0.534
#   - p-value: 1.843e-09
#   - Significant
#
# Optimal crossover_rate for run_time: 0.307 (Minimum run_time: 3.659)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.295
#   - p-value: 1.767e-03
#   - Significant
# Optimal crossover_rate for error: 0.505 (Minimum error: 0.146)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.246
#   - p-value: 9.673e-03
# ...

# %%
# Run for cxTwoPoint, varying crossover rate
param_ranges = {
    'crossover_method' : ['cxTwoPoint'],
    'crossover_rate' : np.linspace(0.01, 1.0, test_cases)
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}cxTwoPoint.csv')
# Out:
# Processing combinations:   0%|          | 0/330 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 330/330 [23:29<00:00,  4.27s/it, Elapsed=23.49min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}cxTwoPoint.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'crossover_rate', polynomial_degree=2)
# Out:
# Optimal crossover_rate for error: 0.901 (Minimum error: 0.132)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.246
#   - p-value: 9.704e-03
#   - Significant
#
# Optimal crossover_rate for run_time: 0.208 (Minimum run_time: 3.539)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.483
#   - p-value: 8.902e-08
#   - Significant
# Optimal crossover_rate for error: 0.01 (Minimum error: 0.000)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): 0.491
#   - p-value: 5.298e-08
#   - Significant
#
# Optimal crossover_rate for run_time: 0.01 (Minimum run_time: 3.571)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.448
#   - p-value: 9.120e-07
#   - Significant
# Optimal crossover_rate for error: 1.0 (Minimum error: 0.140)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.354
#   - p-value: 1.452e-04
# ...

# %%
# Run for cxUniform, varying crossover rate
param_ranges = {
    'crossover_method' : ['cxUniform'],
    'crossover_rate' : np.linspace(0.01, 1.0, test_cases)
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}cxUniform.csv')
# Out:
# Processing combinations:   0%|          | 0/330 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 330/330 [29:07<00:00,  5.30s/it, Elapsed=29.13min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}cxUniform.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'crossover_rate', polynomial_degree=2)
# Out:
# Optimal crossover_rate for error: 0.901 (Minimum error: 0.125)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.391
#   - p-value: 2.362e-05
#   - Significant
#
# Optimal crossover_rate for run_time: 0.6040000000000001 (Minimum run_time: 4.025)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.245
#   - p-value: 1.001e-02
#   - Significant
# Optimal crossover_rate for error: 0.109 (Minimum error: 0.000)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): 0.569
#   - p-value: 9.118e-11
#   - Significant
#
# Optimal crossover_rate for run_time: 0.109 (Minimum run_time: 4.001)
# Relationship between crossover_rate and run_time:
#   - Correlation Coefficient (r): 0.623
#   - p-value: 3.724e-13
#   - Significant
# Optimal crossover_rate for error: 0.505 (Minimum error: 0.154)
# Relationship between crossover_rate and error:
#   - Correlation Coefficient (r): -0.188
# ...

# %%
# Test to see if crossover_prob affects the optimal crossover_rate

param_ranges = {
    'crossover_method' : ['cxKPoint'],
    'crossover_points' : np.linspace(1, 10, test_cases, dtype=int),
    'crossover_rate' : np.linspace(0.1, 1, test_cases)
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}cxKPoint.csv')
# Out:
# Processing combinations:   0%|          | 0/3630 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations: 100%|██████████| 3630/3630 [4:46:59<00:00,  4.74s/it, Elapsed=4.78h, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}cxKPoint.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    heatmap(filtered_df, target_expression, 'crossover_points', 'crossover_rate')
# Out:
# Optimal crossover_points for error: 0.730
# Optimal crossover_rate for error: 7.000
#   - Average error: 0.133
#
# Statistical Test for error:
#   - Statistic: 109.000
#   - p-value: 4.820e-01
#   - Not Significant
#
# Optimal crossover_points for run_time: 0.280
# Optimal crossover_rate for run_time: 2.000
#   - Average run_time: 2.800
#
# Statistical Test for run_time:
#   - Statistic: 109.000
#   - p-value: 4.820e-01
#   - Not Significant
# Optimal crossover_points for error: 0.100
# Optimal crossover_rate for error: 5.000
#   - Average error: 0.000
#
# Statistical Test for error:
#   - Statistic: 109.000
#   - p-value: 4.820e-01
#   - Not Significant
#
# Optimal crossover_points for run_time: 0.370
# Optimal crossover_rate for run_time: 1.000
#   - Average run_time: 2.743
#
# Statistical Test for run_time:
#   - Statistic: 109.000
#   - p-value: 4.820e-01
#   - Not Significant
# Optimal crossover_points for error: 0.460
# Optimal crossover_rate for error: 5.000
# ...

# %%
# Evaluate cxOnePoint
param_ranges = {
    'crossover_method' : ['cxOnePoint'],
    'crossover_rate' : [1]
}
cxOnePoint_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate cxTwoPoint
param_ranges = {
    'crossover_method' : ['cxTwoPoint'],
    'crossover_rate' : [1]
}
cxTwoPoint_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate cxUniform
param_ranges = {
    'crossover_method' : ['cxUniform'],
    'crossover_rate' : [1]
}
cxUniform_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Evaluate cxKPoint
param_ranges = {
    'crossover_method' : ['cxKPoint'],
    'crossover_points' : [3],
    'crossover_rate' : [1]
}
cxKPoint_df = test_params(param_ranges, target_expressions, lineages, kwargs)

# Concatenate all results, and save to csv
results_df = pd.concat([cxOnePoint_df, cxTwoPoint_df, cxUniform_df, cxKPoint_df])
results_df.to_csv(f'{shared_data_dir}crossover_comparison.csv', index=False)
# Out:
# ...
# Processing combinations: 100%|██████████| 30/30 [01:54<00:00,  3.82s/it, Elapsed=1.91min, ETA=0.00s]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}crossover_comparison.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    distribution_plot(filtered_df, target_expression, 'crossover_method')
# Out:
# Optimal crossover_method for error: cxTwoPoint (Average error: 0.131)
# ANOVA Test for error by crossover_method:
#   - F-statistic: 3.665
#   - p-value: 2.107e-02
#   - Significant
#
# Optimal crossover_method for run_time: cxKPoint (Average run_time: 3.594)
# ANOVA Test for run_time by crossover_method:
#   - F-statistic: 9.693
#   - p-value: 7.928e-05
#   - Significant
# Optimal crossover_method for error: cxKPoint (Average error: 0.000)
# ANOVA Test for error by crossover_method:
#   - F-statistic: 2.704
#   - p-value: 5.978e-02
#   - Not Significant
#
# Optimal crossover_method for run_time: cxKPoint (Average run_time: 3.570)
# ANOVA Test for run_time by crossover_method:
#   - F-statistic: 20.192
#   - p-value: 7.589e-08
#   - Significant
# Optimal crossover_method for error: cxOnePoint (Average error: 0.158)
# ANOVA Test for error by crossover_method:
#   - F-statistic: 5.297
#   - p-value: 3.962e-03
#   - Significant
#
# ...

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}crossover_comparison.csv')
filtered_df = results_df[results_df['target_expression'] != 0.5]
distribution_plot(filtered_df, '0 and 1', 'crossover_method')
# Out:
# Optimal crossover_method for error: cxOnePoint (Average error: 0.147)
# ANOVA Test for error by crossover_method:
#   - F-statistic: 3.560
#   - p-value: 1.807e-02
#   - Significant
#
# Optimal crossover_method for run_time: cxKPoint (Average run_time: 3.579)
# ANOVA Test for run_time by crossover_method:
#   - F-statistic: 21.380
#   - p-value: 3.845e-10
#   - Significant

# %% [markdown]
# ### Testing convergence
# ---

# %%
target_expressions = [0]

# All crossover methods
param_ranges = {
    'crossover_method' : ['cxOnePoint', 'cxTwoPoint', 'cxUniform', 'cxKPoint'],
    'crossover_points' : [3],
    'crossover_rate' : [1]
}
results_dfs = test_param_convergence(param_ranges, target_expressions, lineages, kwargs)
convergence_fill_between(results_dfs)
# Out:
# Processing combinations:   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# ...

# %%
target_expressions = [0]

# cxOnePoint, varying crossover rate
param_ranges = {
    'crossover_method' : ['cxOnePoint'],
    'crossover_rate' : [0.01, 0.1, 0.5, 1]
}
results_dfs = test_param_convergence(param_ranges, target_expressions, lineages, kwargs)
convergence_fill_between(results_dfs)
# Out:
# Processing combinations:   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations:  25%|██▌       | 1/4 [00:34<01:44, 34.76s/it, Elapsed=34.76s, ETA=1.74min]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# ...

# %%
target_expressions = [0]

# cxKPoint, varying crossover points
param_ranges = {
    'crossover_method' : ['cxKPoint'],
    'crossover_rate' : [1],
    'crossover_points' : [1, 3, 5, 10]
}
results_dfs = test_param_convergence(param_ranges, target_expressions, lineages, kwargs)
convergence_fill_between(results_dfs)
# Out:
# Processing combinations:   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations:  25%|██▌       | 1/4 [00:48<02:26, 48.99s/it, Elapsed=48.99s, ETA=2.45min]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# ...
