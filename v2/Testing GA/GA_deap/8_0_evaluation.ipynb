# %%
import numpy as np

from function_modules.function_module import *

# %%
# Shared directory to save results 
shared_data_dir = 'Data/evaluation/'

# Shared GA parameters
kwargs = {
    'cnn_model_path': '../../Models/CNN_6_1_2.keras',
    'masked_sequence': 'AATACTAGAGGTCTTCCGACNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNGTGTGGGCGGGAAGACAACTAGGGG',
    'seed': 0,
}

# Testing parameters
target_expressions = [0, 0.5, 1]
lineages = 10
test_cases = 10

# %%
# Vary population_size
param_ranges = {
    'population_size' : np.linspace(50, 500, test_cases, dtype=int),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}population_size.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]
# WARNING:tensorflow:From c:\Users\rsore\Documents\GitHub\promoter-sequence-transcription-rates\v2\Testing GA\GA_deap\GA\CNN.py:66: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations:  49%|████▉     | 147/300 [13:22<20:40,  8.11s/it, Elapsed=13.38min, ETA=13.92min]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}population_size.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'population_size', polynomial_degree=2)
# Out:
# Optimal population_size for error: 400 (Minimum error: 0.126)
# Relationship between population_size and error:
#   - Correlation Coefficient (r): -0.548
#   - p-value: 3.653e-09
#   - Significant
#
# Optimal population_size for run_time: 50 (Minimum run_time: 2.724)
# Relationship between population_size and run_time:
#   - Correlation Coefficient (r): 0.861
#   - p-value: 1.480e-30
#   - Significant
# Optimal population_size for error: 450 (Minimum error: 0.000)
# Relationship between population_size and error:
#   - Correlation Coefficient (r): -0.475
#   - p-value: 6.059e-07
#   - Significant
#
# Optimal population_size for run_time: 50 (Minimum run_time: 3.207)
# Relationship between population_size and run_time:
#   - Correlation Coefficient (r): 0.864
#   - p-value: 6.076e-31
#   - Significant
# Optimal population_size for error: 500 (Minimum error: 0.108)
# Relationship between population_size and error:
#   - Correlation Coefficient (r): -0.561
#   - p-value: 1.317e-09
#   - Significant
#
# Optimal population_size for run_time: 50 (Minimum run_time: 2.780)
# Relationship between population_size and run_time:
#   - Correlation Coefficient (r): 0.944
#   - p-value: 5.069e-49
#   - Significant

# %%
# Vary generations
param_ranges = {
    'generations' : np.linspace(50, 500, test_cases, dtype=int),
}
results_df = test_params(param_ranges, target_expressions, lineages, kwargs, to_csv=f'{shared_data_dir}generations.csv')
# Out:
# Processing combinations:   0%|          | 0/300 [00:00<?, ?it/s]c:\Users\rsore\anaconda3\envs\TX_prediction\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing combinations:   3%|▎         | 10/300 [00:33<16:43,  3.46s/it, Elapsed=33.31s, ETA=16.10min]

# %%
# Read results (if necessary) and plot
results_df = pd.read_csv(f'{shared_data_dir}generations.csv')

for target_expression in target_expressions:
    filtered_df = results_df[results_df['target_expression'] == target_expression]
    scatter_plot(filtered_df, target_expression, 'generations', polynomial_degree=2)
# Out:
# Optimal generations for error: 150 (Minimum error: 0.126)
# Relationship between generations and error:
#   - Correlation Coefficient (r): -0.171
#   - p-value: 8.814e-02
#   - Not Significant
#
# Optimal generations for run_time: 50 (Minimum run_time: 2.718)
# Relationship between generations and run_time:
#   - Correlation Coefficient (r): 0.994
#   - p-value: 5.838e-95
#   - Significant
# Optimal generations for error: 450 (Minimum error: 0.000)
# Relationship between generations and error:
#   - Correlation Coefficient (r): -0.589
#   - p-value: 1.150e-10
#   - Significant
#
# Optimal generations for run_time: 50 (Minimum run_time: 3.198)
# Relationship between generations and run_time:
#   - Correlation Coefficient (r): 0.996
#   - p-value: 2.441e-107
#   - Significant
# Optimal generations for error: 350 (Minimum error: 0.140)
# Relationship between generations and error:
#   - Correlation Coefficient (r): -0.300
#   - p-value: 2.392e-03
#   - Significant
#
# Optimal generations for run_time: 50 (Minimum run_time: 3.254)
# Relationship between generations and run_time:
#   - Correlation Coefficient (r): 0.998
#   - p-value: 4.681e-116
#   - Significant
